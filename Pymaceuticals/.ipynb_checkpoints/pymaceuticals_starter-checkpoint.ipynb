# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# File to Load (Remember to Change These)
mouse_drug_data_to_load = "data/mouse_drug_data.csv"
clinical_trial_data_to_load = "data/clinicaltrial_data.csv"

# Read the Mouse and Drug Data and the Clinical Trial Data
mouse_df = pd.read_csv(mouse_drug_data_to_load)
clinical_df = pd.read_csv(clinical_trial_data_to_load)

# %%
mouse_df.head()
# Out:
#   Mouse ID      Drug
# 0     f234  Stelasyn
# 1     x402  Stelasyn
# 2     a492  Stelasyn
# 3     w540  Stelasyn
# 4     v764  Stelasyn

# %%
clinical_df.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0     b128          0                45.0                 0
# 1     f932          0                45.0                 0
# 2     g107          0                45.0                 0
# 3     a457          0                45.0                 0
# 4     c819          0                45.0                 0

# %%
# Combine the data into a single dataset
merge_outer_df = pd.merge(mouse_df, clinical_df, on='Mouse ID', how='outer')
# Display the data table for preview
merge_outer_df
# Out:
#      Mouse ID      Drug  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0        f234  Stelasyn          0           45.000000                 0
# 1        f234  Stelasyn          5           47.313491                 0
# 2        f234  Stelasyn         10           47.904324                 0
# 3        f234  Stelasyn         15           48.735197                 1
# 4        f234  Stelasyn         20           51.112713                 2
# ...       ...       ...        ...                 ...               ...
# 1901     j235   Placebo          0           45.000000                 0
# 1902     j235   Placebo          5           46.588820                 0
# 1903     j235   Placebo         10           48.018788                 1
# 1904     j235   Placebo         15           51.161138                 1
# 1905     j235   Placebo         20           52.942902                 1
#
# [1906 rows x 5 columns]

# %% [markdown]
# ## Tumor Response to Treatment

# %%
# Store the Mean Tumor Volume Data Grouped by Drug and Timepoint 
df_drug_mean = merge_outer_df[['Drug','Timepoint', 'Tumor Volume (mm3)']].groupby(['Drug','Timepoint'], as_index=False).mean()

# Convert to DataFrame
df_drug_mean
# Preview DataFrame
df_drug_mean.head()
# Out:
#         Drug  Timepoint  Tumor Volume (mm3)
# 0  Capomulin          0           45.000000
# 1  Capomulin          5           44.266086
# 2  Capomulin         10           43.084291
# 3  Capomulin         15           42.064317
# 4  Capomulin         20           40.716325

# %%
merge_outer_df.head()
# Store the Standard Error of Tumor Volumes Grouped by Drug and Timepoint
df_tumor_sem = merge_outer_df[['Drug','Timepoint','Tumor Volume (mm3)']].groupby(['Drug','Timepoint']).sem()['Tumor Volume (mm3)'].to_frame().reset_index()
# Convert to DataFrame
df_tumor_sem.head()
# Preview DataFrame
# Out:
#         Drug  Timepoint  Tumor Volume (mm3)
# 0  Capomulin          0            0.000000
# 1  Capomulin          5            0.448593
# 2  Capomulin         10            0.702684
# 3  Capomulin         15            0.838617
# 4  Capomulin         20            0.909731

# %%
# Minor Data Munging to Re-Format the Data Frames
pivot_drug_mean = df_drug_mean.pivot(index='Timepoint', columns='Drug', values='Tumor Volume (mm3)')

# Preview that Reformatting worked
pivot_drug_mean.head()
# Out:
# Drug       Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol    Placebo  \
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# 5          44.266086  46.503051  47.062001  47.389175  46.796098  47.125589
# 10         43.084291  48.285125  49.403909  49.582269  48.694210  49.423329
# 15         42.064317  50.094055  51.296397  52.399974  50.933018  51.359742
# 20         40.716325  52.157049  53.197691  54.920935  53.644087  54.364417
#
# Drug        Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# 5          47.248967  43.944859  47.527452  46.851818
# 10         49.101541  42.531957  49.463844  48.689881
# 15         51.067318  41.495061  51.529409  50.779059
# 20         53.346737  40.238325  54.067395  53.170334

# %%
pivot_drug_sem = df_tumor_sem.pivot(index='Timepoint', columns='Drug', values='Tumor Volume (mm3)')
pivot_drug_sem.head()
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.448593  0.164505   0.235102  0.264819  0.202385  0.218091
# 10          0.702684  0.236144   0.282346  0.357421  0.319415  0.402064
# 15          0.838617  0.332053   0.357705  0.580268  0.444378  0.614461
# 20          0.909731  0.359482   0.476210  0.726484  0.595260  0.839609
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# 5          0.231708  0.482955  0.239862   0.188950
# 10         0.376195  0.720225  0.433678   0.263949
# 15         0.466109  0.770432  0.493261   0.370544
# 20         0.555181  0.786199  0.621889   0.533182

# %%
### Generate the Plot (with Error Bars)
plt.errorbar(pivot_drug_mean.index, pivot_drug_mean["Capomulin"], pivot_drug_sem["Capomulin"], color="r", marker ="o", markersize=3, linewidth=0.5)
plt.errorbar(pivot_drug_mean.index, pivot_drug_mean["Ceftamin"], pivot_drug_sem["Ceftamin"], color="b", marker ="o", markersize=3, linewidth=0.5)
plt.errorbar(pivot_drug_mean.index, pivot_drug_mean["Infubinol"], pivot_drug_sem["Infubinol"], color="g", marker ="o", markersize=3, linewidth=0.5)
plt.errorbar(pivot_drug_mean.index, pivot_drug_mean["Ketapril"], pivot_drug_sem["Ketapril"], color="y", marker ="o", markersize=3, linewidth=0.5)
plt.errorbar(pivot_drug_mean.index, pivot_drug_mean["Naftisol"], pivot_drug_sem["Naftisol"], color="orange", marker ="o", markersize=3, linewidth=0.5)
plt.errorbar(pivot_drug_mean.index, pivot_drug_mean["Placebo"], pivot_drug_sem["Placebo"], color="brown", marker ="o", markersize=3, linewidth=0.5)
plt.errorbar(pivot_drug_mean.index, pivot_drug_mean["Propriva"], pivot_drug_sem["Propriva"], color="black", marker ="o", markersize=3, linewidth=0.5)
plt.errorbar(pivot_drug_mean.index, pivot_drug_mean["Propriva"], pivot_drug_sem["Propriva"], color="black", marker ="o", markersize=3, linewidth=0.5)
plt.errorbar(pivot_drug_mean.index, pivot_drug_mean["Ramicane"], pivot_drug_sem["Ramicane"], color="grey", marker ="o", markersize=3, linewidth=0.5)
plt.errorbar(pivot_drug_mean.index, pivot_drug_mean["Stelasyn"], pivot_drug_sem["Stelasyn"], color="purple", marker ="o", markersize=3, linewidth=0.5)
plt.errorbar(pivot_drug_mean.index, pivot_drug_mean["Zoniferol"], pivot_drug_sem["Zoniferol"], color="aqua", marker ="o", markersize=3, linewidth=0.5)
plt.title('Tumor response to treatment')
plt.xlabel('Time (days)')
plt.ylabel('Tumor Volume (mm3)')
plt.xlim(0,46)
plt.ylim(34,72)
plt.xticks(np.arange(0, 46, 5))
plt.yticks(np.arange(35,75,5))
plt.grid()
# Save the Figure
plt.savefig("tumor_response_to_treatment.pdf")
plt.show()
#Me falta dar formato y poner las legendas

# %% [markdown]
# ## Metastatic Response to Treatment

# %%
# Store the Mean Met. Site Data Grouped by Drug and Timepoint 
df_metastic_mean = merge_outer_df[['Drug','Timepoint','Metastatic Sites']].groupby(['Drug','Timepoint'], as_index=False).mean()
# Convert to DataFrame
# Preview DataFrame
df_metastic_mean.head()
# Out:
#         Drug  Timepoint  Metastatic Sites
# 0  Capomulin          0          0.000000
# 1  Capomulin          5          0.160000
# 2  Capomulin         10          0.320000
# 3  Capomulin         15          0.375000
# 4  Capomulin         20          0.652174

# %%
# Store the Standard Error associated with Met. Sites Grouped by Drug and Timepoint 
df_metastic_sem = merge_outer_df[['Drug','Timepoint','Metastatic Sites']].groupby(['Drug','Timepoint']).sem()['Metastatic Sites'].to_frame().reset_index()
# Convert to DataFrame

# Preview DataFrame
df_metastic_sem
# Out:
#          Drug  Timepoint  Metastatic Sites
# 0   Capomulin          0          0.000000
# 1   Capomulin          5          0.074833
# 2   Capomulin         10          0.125433
# 3   Capomulin         15          0.132048
# 4   Capomulin         20          0.161621
# ..        ...        ...               ...
# 95  Zoniferol         25          0.236621
# 96  Zoniferol         30          0.248168
# 97  Zoniferol         35          0.285714
# 98  Zoniferol         40          0.299791
# 99  Zoniferol         45          0.286400
#
# [100 rows x 3 columns]

# %%
# Minor Data Munging to Re-Format the Data Frames
pivot_metastic_mean = df_metastic_mean.pivot(index='Timepoint', columns='Drug', values='Metastatic Sites')

# Preview that Reformatting worked
pivot_metastic_mean
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.160000  0.380952   0.280000  0.304348  0.260870  0.375000
# 10          0.320000  0.600000   0.666667  0.590909  0.523810  0.833333
# 15          0.375000  0.789474   0.904762  0.842105  0.857143  1.250000
# 20          0.652174  1.111111   1.050000  1.210526  1.150000  1.526316
# 25          0.818182  1.500000   1.277778  1.631579  1.500000  1.941176
# 30          1.090909  1.937500   1.588235  2.055556  2.066667  2.266667
# 35          1.181818  2.071429   1.666667  2.294118  2.266667  2.642857
# 40          1.380952  2.357143   2.100000  2.733333  2.466667  3.166667
# 45          1.476190  2.692308   2.111111  3.363636  2.538462  3.272727
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# ...

# %%
pivot_metastic_sem = df_metastic_sem.pivot(index='Timepoint', columns='Drug', values='Metastatic Sites')
pivot_metastic_sem
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.074833  0.108588   0.091652  0.098100  0.093618  0.100947
# 10          0.125433  0.152177   0.159364  0.142018  0.163577  0.115261
# 15          0.132048  0.180625   0.194015  0.191381  0.158651  0.190221
# 20          0.161621  0.241034   0.234801  0.236680  0.181731  0.234064
# 25          0.181818  0.258831   0.265753  0.288275  0.185240  0.263888
# 30          0.172944  0.249479   0.227823  0.347467  0.266667  0.300264
# 35          0.169496  0.266526   0.224733  0.361418  0.330464  0.341412
# 40          0.175610  0.289128   0.314466  0.315725  0.321702  0.297294
# 45          0.202591  0.286101   0.309320  0.278722  0.351104  0.304240
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# ...

# %%
# Generate the Plot (with Error Bars)
plt.errorbar(pivot_metastic_mean.index, pivot_metastic_mean["Capomulin"], pivot_metastic_sem["Capomulin"], color="r", marker ="o", markersize=3, linewidth=0.5)
plt.errorbar(pivot_metastic_mean.index, pivot_metastic_mean["Ceftamin"], pivot_metastic_sem["Ceftamin"], color="b", marker ="o", markersize=3, linewidth=0.5)
plt.errorbar(pivot_metastic_mean.index, pivot_metastic_mean["Infubinol"], pivot_metastic_sem["Infubinol"], color="g", marker ="o", markersize=3, linewidth=0.5)
plt.errorbar(pivot_metastic_mean.index, pivot_metastic_mean["Ketapril"], pivot_metastic_sem["Ketapril"], color="y", marker ="o", markersize=3, linewidth=0.5)
plt.errorbar(pivot_metastic_mean.index, pivot_metastic_mean["Naftisol"], pivot_metastic_sem["Naftisol"], color="orange", marker ="o", markersize=3, linewidth=0.5)
plt.errorbar(pivot_metastic_mean.index, pivot_metastic_mean["Placebo"], pivot_metastic_sem["Placebo"], color="brown", marker ="o", markersize=3, linewidth=0.5)
plt.errorbar(pivot_metastic_mean.index, pivot_metastic_mean["Propriva"], pivot_metastic_sem["Propriva"], color="black", marker ="o", markersize=3, linewidth=0.5)
plt.errorbar(pivot_metastic_mean.index, pivot_metastic_mean["Propriva"], pivot_metastic_sem["Propriva"], color="black", marker ="o", markersize=3, linewidth=0.5)
plt.errorbar(pivot_metastic_mean.index, pivot_metastic_mean["Ramicane"], pivot_metastic_sem["Ramicane"], color="grey", marker ="o", markersize=3, linewidth=0.5)
plt.errorbar(pivot_metastic_mean.index, pivot_metastic_mean["Stelasyn"], pivot_metastic_sem["Stelasyn"], color="purple", marker ="o", markersize=3, linewidth=0.5)
plt.errorbar(pivot_metastic_mean.index, pivot_metastic_mean["Zoniferol"], pivot_metastic_sem["Zoniferol"], color="aqua", marker ="o", markersize=3, linewidth=0.5)
plt.title('Metastatic response to treatment')
plt.xlabel('Time (days)')
plt.ylabel('Metastatic Sites')
plt.xlim(0,45)
plt.ylim(0,4)
plt.grid()
# Save the Figure

# Show the Figure

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/spread.png)

# %% [markdown]
# ## Survival Rates

# %%
# Store the Count of Mice Grouped by Drug and Timepoint (W can pass any metric)

# Convert to DataFrame

# Preview DataFrame

# %%
# Minor Data Munging to Re-Format the Data Frames

# Preview the Data Frame

# %%
# Generate the Plot (Accounting for percentages)

# Save the Figure

# Show the Figure
plt.show()

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/survival.png)

# %% [markdown]
# ## Summary Bar Graph

# %%
# Calculate the percent changes for each drug

# Display the data to confirm

# %%
# Store all Relevant Percent Changes into a Tuple


# Splice the data between passing and failing drugs


# Orient widths. Add labels, tick marks, etc. 


# Use functions to label the percentages of changes


# Call functions to implement the function calls


# Save the Figure


# Show the Figure
fig.show()

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/change.png)
